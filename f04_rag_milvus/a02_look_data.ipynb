# %%
import pandas as pd
# Out:
# f:\a02_env_ware\ana\Lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('SNOMED_5000.csv')
df.shape
# Out:
# (5002, 11)

# %%
df.head()
# Out:
#    concept_id                                       concept_name    domain_id  \
# 0    44784427  Post diphtheria, tetanus and pertussis vaccina...    Condition
# 1     4230968  Tympanoplasty type V with fenestra in semicirc...    Procedure
# 2     4001321  Primary malignant neoplasm of peripheral nerve...    Condition
# 3     4131055                                 Periungual fibroma    Condition
# 4     4271668                                   Swelling feature  Observation
#
#   vocabulary_id   concept_class_id standard_concept  concept_code  \
# 0        SNOMED           Disorder                S     698578005
# 1        SNOMED          Procedure                S      89246001
# 2        SNOMED           Disorder                S     109943004
# 3        SNOMED           Disorder                S     264561009
# 4        SNOMED  Observable Entity                S     364642001
#
#    valid_start_date  valid_end_date  invalid_reason  \
# ...

# %%
'''
concept_id = OMOP 生态中的标识
concept_name = 概念名称 (用自然语言书写) ->>> 通过这个字段的embedding进行查找
domain_id = 所属医疗领域 
vocabulary_id = 术语系统 [表示concept_code 来自 SNOMED 词汇表]
concept_class_id = 概念类别
standard_concept = S代表标准概念 空白代表非标准概念	
concept_code = SNOMED 生态中的标识


valid_start_date = 概念开始时间 
valid_end_date = 概念失效时间 [通常是20991231]
invalid_reason = 概念失效原因 [如果概念已经被舍弃 此处说明原因]

FSN = 完全限定名称(类别)   [可能包含多个同义词 用分号隔开]
'''


''' 
如何使用数据



'''
