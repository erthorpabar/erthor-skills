# %% [markdown]
# 0 导入包

# %%
'''必要加载项 model tokenizer 配置文件'''

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
# Out:
# '\n推理需要 trasformer库\n1model 2tokenizer 3加载配置文件\n'

# %% [markdown]
# 1 加载模型

# %%
model_id = "facebook/opt-125m"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,

    # 加载设备
    device_map={"": 0}, # k代表参数名前缀，空代表所有模型参数 v代表在哪张gpu上运行
)

# %% [markdown]
# 2 测试输出

# %%
# 输入需要与模型在同一个设备上
text = "Merry Christmas! I'm glad to"
token = tokenizer(text, return_tensors="pt").to(model.device) # 输入与模型权重在相同设备上
out = model.generate(**token, max_new_tokens=64)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# Merry Christmas! I'm glad to hear you're doing well!
# Thank you! I'm glad you're doing well too!
