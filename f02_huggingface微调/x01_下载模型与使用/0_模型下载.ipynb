# %%
# ——————huggingface各种库的作用——————
# pip install transformers # 模型 加载
# pip install datasets # 数据集 加载
# pip install peft # 微调

# pip install trl # 强化学习
# pip install bitsandbytes # 量化加载

# %%
# ——————登录huggingface——————
from huggingface_hub import login
login(token="hf-key")

# %%
# ——————huggingface镜像——————
export HF_ENDPOINT= 'https://hf-mirror.com'

# %%
# modelscope 下载模型
from modelscope.hub.snapshot_download import snapshot_download
model_dir = snapshot_download('qwen/Qwen2-7B-Instruct', cache_dir='E:\\a0LLM', revision='master')
