# %% [markdown]
# 0 导入包

# %%
from transformers import AutoTokenizer
from datasets import load_from_disk

# %% [markdown]
# 1 tokenizer

# %%
model_path = "google/gemma-2b-it" # 模型名字或路径
tokenizer = AutoTokenizer.from_pretrained(model_path)
# Out:
# D:\0env_config\1py\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# 2 加载数据集

# %%
dataset = load_from_disk('2prompt_data')
dataset
# Out:
# Dataset({
#     features: ['input', 'output', 'prompt'],
#     num_rows: 4260
# })

# %% [markdown]
# 3 把某列token化

# %%
# 把某一列数据tokne化
dataset = dataset.map(lambda x: # x相当于dataset[i]
                      tokenizer(x["prompt"],padding='max_length',truncation=True), # 把dataset[i]["prompt"]token化
                      remove_columns=['input', 'output'], # 删除哪些列
                      batched=True)
# Out:
# Map:   0%|          | 0/4260 [00:00<?, ? examples/s]
# Asking to pad to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no padding.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
dataset
# Out:
# Dataset({
#     features: ['prompt', 'input_ids', 'attention_mask'],
#     num_rows: 4260
# })

# %% [markdown]
# 4 切分数据集

# %%
# 切分为train，和test数据集
dataset = dataset.train_test_split(train_size=0.8, test_size=0.2, seed=42, shuffle=True)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'input_ids', 'attention_mask'],
#         num_rows: 3408
#     })
#     test: Dataset({
#         features: ['prompt', 'input_ids', 'attention_mask'],
#         num_rows: 852
#     })
# })

# %% [markdown]
# 5 保存

# %%
dataset.save_to_disk('3token_dataset')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/3408 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/852 [00:00<?, ? examples/s]
