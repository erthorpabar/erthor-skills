# %%
from datasets import load_dataset, Audio

# 只加载前1000条数据
dataset = load_dataset("facebook/voxpopuli", "en", split="test[:200]")
print(len(dataset))
# Out:
# d:\env_config\py\lib\site-packages\datasets\load.py:1491: FutureWarning: The repository for facebook/voxpopuli contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/facebook/voxpopuli
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from datasets import load_dataset, Audio
#       3 # 只加载前1000条数据
# ----> 4 dataset = load_dataset("facebook/voxpopuli", "en", split="test[:200]")
#       5 print(len(dataset))
#
# ...

# %%
dataset
