# %%
import json

# %%
with open('./services/comfyui_api/two_character_01_api.json', 'r') as f:
    workflow = json.load(f)

workflow
# Out:
# {'11': {'inputs': {'unet_name': 'flux-dev-fp8.safetensors',
#    'weight_dtype': 'fp8_e4m3fn'},
#   'class_type': 'UNETLoader',
#   '_meta': {'title': 'Load Diffusion Model'}},
#  '15': {'inputs': {'clip_name1': 't5xxl_fp8_e4m3fn.safetensors',
#    'clip_name2': 'clip_l.safetensors',
#    'type': 'flux',
#    'device': 'default'},
#   'class_type': 'DualCLIPLoader',
#   '_meta': {'title': 'DualCLIPLoader'}},
#  '16': {'inputs': {'vae_name': 'ae.safetensors'},
#   'class_type': 'VAELoader',
#   '_meta': {'title': 'Load VAE'}},
#  '18': {'inputs': {'lora_name': 'flux_lora/推文韩漫都市言情_V1.0.safetensors',
#    'strength_model': 1,
#    'model': ['11', 0]},
#   'class_type': 'LoraLoaderModelOnly',
#   '_meta': {'title': 'LoraLoaderModelOnly'}},
#  '20': {'inputs': {'text': ['35', 0], 'clip': ['15', 0]},
#   'class_type': 'CLIPTextEncode',
#   '_meta': {'title': 'CLIP Text Encode (Prompt)'}},
#  '22': {'inputs': {'noise': ['26', 0],
#    'guider': ['23', 0],
#    'sampler': ['25', 0],
# ...

# %%
workflow['11']['inputs']['unet_name'] # 模型名称
# Out:
# 'flux-dev-fp8.safetensors'

# %%
workflow['18']['inputs']['lora_name'] # 模型lora画风
# Out:
# 'flux_lora/推文韩漫都市言情_V1.0.safetensors'

# %%
workflow['36']['inputs']['input_int'] # 宽
# Out:
# 1024

# %%
workflow['37']['inputs']['input_int'] # 高
# Out:
# 1024

# %%
workflow['35']['inputs']['input_str'] # 提示词
# Out:
# 'a girl'

# %%
workflow['26']['inputs']['noise_seed'] # 随机种子
# Out:
# 788044528812983
