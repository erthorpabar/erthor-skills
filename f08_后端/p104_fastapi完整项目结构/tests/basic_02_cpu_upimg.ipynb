# %%
import requests
import time  # 导入 time 模块

start_time = time.time() # 开始时间

# # 测试请求数据
url = "http://127.0.0.1:7005/basic/cpu/upimg"  # 根据你的服务地址调整

# 测试1
# data = {
#     "img_path": "http://61.49.53.9:6017/view?filename=ComfyUI_00038_.png&type=output"
# }

# 测试2
data = {
    "img_path": "ccc.png"
}

# 发送 POST 请求
response = requests.post(url, json=data)


end_time = time.time() # 结束时间



total_time = end_time - start_time # 总耗时
print(f"生图+返图耗时: {total_time:.2f} 秒")

print(response.json())
# Out:
# 生图+返图耗时: 0.04 秒
# {'name': 'ccc.png', 'subfolder': '', 'type': 'input'}
