# %%
# 检查连接情况
import requests
url = "http://127.0.0.1:8188/"  
response = requests.get(url)
print(response.json())
# Out:
# {'message': 'ok'}

# %%
# 查询队列长度(包括正在生成的)
import requests
url = "http://127.0.0.1:8188/queue" 
response = requests.get(url)
print(response.json())
# Out:
# {'queue_length': 0}

# %%
# 提交任务
import requests
url = "http://127.0.0.1:8188/prompt"
data = { "prompt_data": "生成一个美丽的风景图片"}
response = requests.post(url,json=data)
print(response.json())
# Out:
# {'task': '93e2b1ca-6ef6-4d24-abf1-3d1c0bc9b620'}
